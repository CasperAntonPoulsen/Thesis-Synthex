# %%
import pandas as pd
import os
import shutil

# %%
data_dir = "/dtu/p1/johlau/Thesis-Synthex/data/"

# %%
cropped_dirs = [i for i in os.listdir(data_dir) if i.endswith("CROPPED")]

# %%
for dir in cropped_dirs:
    paths = os.listdir(data_dir+dir)

    for path in paths:
        print(data_dir+dir+ "/"+path)
        os.rename(data_dir+dir+ "/"+path, data_dir+dir+ "/"+dir+path)
# Out:
# /dtu/p1/johlau/Thesis-Synthex/data/RAD-ChestCT-CROPPED/trn06611.nii.gz.png
# /dtu/p1/johlau/Thesis-Synthex/data/RAD-ChestCT-CROPPED/val27360.nii.gz.png
# /dtu/p1/johlau/Thesis-Synthex/data/RAD-ChestCT-CROPPED/val26794.nii.gz.png
# /dtu/p1/johlau/Thesis-Synthex/data/RAD-ChestCT-CROPPED/trn10697.nii.gz.png
# /dtu/p1/johlau/Thesis-Synthex/data/RAD-ChestCT-CROPPED/val26619.nii.gz.png
# /dtu/p1/johlau/Thesis-Synthex/data/RAD-ChestCT-CROPPED/trn17714.nii.gz.png
# /dtu/p1/johlau/Thesis-Synthex/data/RAD-ChestCT-CROPPED/trn06542.nii.gz.png
# /dtu/p1/johlau/Thesis-Synthex/data/RAD-ChestCT-CROPPED/trn22619.nii.gz.png
# /dtu/p1/johlau/Thesis-Synthex/data/RAD-ChestCT-CROPPED/trn08122.nii.gz.png
# /dtu/p1/johlau/Thesis-Synthex/data/RAD-ChestCT-CROPPED/trn15091.nii.gz.png
# /dtu/p1/johlau/Thesis-Synthex/data/LIDC-IDRI-DRR-CROPPED/LIDC-IDRI-0066.png
# /dtu/p1/johlau/Thesis-Synthex/data/LIDC-IDRI-DRR-CROPPED/LIDC-IDRI-0621.png
# ...

# %%
for dir in cropped_dirs:
    paths = os.listdir(data_dir+dir)

    for path in paths:
        print(data_dir+dir+ "/"+path)
        os.rename( data_dir+dir+ "/"+dir+path, data_dir+dir+ "/"+dir+"|"+path)
