# %%
from arguments import add_nbia_args
import argparse
import pandas as pd
from tcia_utils import nbia
import ast

import datetime

import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 4
#       2 import argparse
#       3 import pandas as pd
# ----> 4 from tcia_utils import nbia
#       5 import ast
#       7 import datetime
#
# File ~/.local/lib/python3.9/site-packages/tcia_utils/__init__.py:1
# ----> 1 from . import nbia
#       2 from . import datacite
#       3 from . import pathdb
#
# File ~/.local/lib/python3.9/site-packages/tcia_utils/nbia.py:22
#      20 import numpy as np
#      21 from ipywidgets import interact
# ---> 22 from tcia_utils.utils import searchDf
#      23 from tcia_utils.utils import format_disk_space
#      24 from tcia_utils.utils import remove_html_tags
#
# File ~/.local/lib/python3.9/site-packages/tcia_utils/utils.py:3
#       1 import pandas as pd
#       2 import inspect
# ----> 3 from bs4 import BeautifulSoup
#       4 from unidecode import unidecode
# ...

# %%
collection = "LIDC-IDRI"
output_dir = "/dtu/p1/johlau/Thesis-Synthex/data/LIDC-IDRI"
api_url = ""

# %%
series = pd.DataFrame()
seriesDescription = nbia.getSeries(collection, api_url = api_url)
series = pd.concat([series, pd.DataFrame(seriesDescription)], ignore_index=True)
# Out:
# 2024-03-17 10:16:16,015:INFO:Calling... https://services.cancerimagingarchive.net/nbia-api/services/v1/getSeries with parameters {'Collection': 'LIDC-IDRI'}

# %%
series[series["PatientID"]=="LIDC-IDRI-0001"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 series[series["PatientID"]=="LIDC-IDRI-0001"]
#
# NameError: name 'series' is not defined

# %%
series.to_dict(orient="records")
# Out:
# [{'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.6279.6001.141365756818074696859567662357',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.6279.6001.175012972118199124641098335511',
#   'Modality': 'DX',
#   'SeriesDate': '2000-01-01 00:00:00.0',
#   'BodyPartExamined': 'CHEST',
#   'SeriesNumber': 3000923.0,
#   'AnnotationsFlag': True,
#   'Collection': 'LIDC-IDRI',
#   'PatientID': 'LIDC-IDRI-0001',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'Revolution XQi ADS_28.2',
#   'SoftwareVersions': 'Ads Application Package VERSION ADS_28.2',
#   'ImageCount': 2,
#   'TimeStamp': '2020-02-21 15:12:42.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.LO9QL9SX',
#   'FileSize': 16357620,
#   'SeriesDescription': nan,
#   'ProtocolName': nan},
# ...

# %%
seriesDescription
# Out:
# [{'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.6279.6001.141365756818074696859567662357',
#   'StudyInstanceUID': '1.3.6.1.4.1.14519.5.2.1.6279.6001.175012972118199124641098335511',
#   'Modality': 'DX',
#   'SeriesDate': '2000-01-01 00:00:00.0',
#   'BodyPartExamined': 'CHEST',
#   'SeriesNumber': 3000923,
#   'AnnotationsFlag': True,
#   'Collection': 'LIDC-IDRI',
#   'PatientID': 'LIDC-IDRI-0001',
#   'Manufacturer': 'GE MEDICAL SYSTEMS',
#   'ManufacturerModelName': 'Revolution XQi ADS_28.2',
#   'SoftwareVersions': 'Ads Application Package VERSION ADS_28.2',
#   'ImageCount': 2,
#   'TimeStamp': '2020-02-21 15:12:42.0',
#   'LicenseName': 'Creative Commons Attribution 3.0 Unported License',
#   'LicenseURI': 'http://creativecommons.org/licenses/by/3.0/',
#   'CollectionURI': 'https://doi.org/10.7937/K9/TCIA.2015.LO9QL9SX',
#   'FileSize': 16357620},
#  {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.6279.6001.188744668142367349818410044874',
# ...

# %%
series[~series["SeriesInstanceUID"].isin(os.listdir(output_dir))]
# Out:
#                                        SeriesInstanceUID  \
# 390    1.3.6.1.4.1.14519.5.2.1.6279.6001.106419850406...
# 391    1.3.6.1.4.1.14519.5.2.1.6279.6001.450501966058...
# 392    1.3.6.1.4.1.14519.5.2.1.6279.6001.259453428008...
# 393    1.3.6.1.4.1.14519.5.2.1.6279.6001.308153138776...
# 394    1.3.6.1.4.1.14519.5.2.1.6279.6001.596908385953...
# ...                                                  ...
# 15111  1.2.276.0.7230010.3.1.3.0.22931.1553305982.919594
# 15112   1.2.276.0.7230010.3.1.3.0.22933.1553305989.80978
# 15113  1.2.276.0.7230010.3.1.3.0.22938.1553306001.545565
# 15114  1.2.276.0.7230010.3.1.3.0.22935.1553305995.312872
# 15115  1.2.276.0.7230010.3.1.3.0.22928.1553305976.617087
#
#                                         StudyInstanceUID Modality  \
# 390    1.3.6.1.4.1.14519.5.2.1.6279.6001.309197613983...       CT
# 391    1.3.6.1.4.1.14519.5.2.1.6279.6001.133142523452...       CT
# 392    1.3.6.1.4.1.14519.5.2.1.6279.6001.110583593061...       CT
# ...

# %%
# Out:
# ['study_metadata_2024-03-04.csv',
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.141365756818074696859567662357',
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.188744668142367349818410044874',
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.244438805420641221879751406199',
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.465203542815096670421396392391',
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.328966172046407489713246745434',
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.187315748963327646100167691452',
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.541650212189696551261299172506',
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.141129481770767608972887619912',
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.127704200987696583405112255999',
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.186489439482736342984904886237',
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.503106584587572008934827316250',
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.935486179338862584391625697780',
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.126739648830679105206897886262',
# ...
